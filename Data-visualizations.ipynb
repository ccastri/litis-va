# %%
# %pip install seaborn
# %pip install matplotlib

# %%
import pandas as pd
import numpy as np
import os
import matplotlib.pylab as plt


# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

# %%
# Get the current working directory
current_directory = os.getcwd()

# Specify the file name
file_name = "static/LISTADO AFILIADOS.xls"

# Combine the current directory and file name
file_path = os.path.join(f"{current_directory}", file_name)
# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)
# Replace 'output_file.csv' with the desired CSV file name
output_file = "output_file.csv"

# Convert the DataFrame to CSV
df.to_csv(output_file, index=False)

# %%
pwd
# Out:
# 'd:\\litis-docker\\litis-ds'

# %%
df_csv=pd.read_csv("output_file.csv")
print(df_csv.shape)
df_csv
# Out:
# (82, 60)
#     Tipo Cotizante  Subtipo Cotizante Subtipo UGPP Tipo Identificacion  \
# 0                1                  7            0                  CC
# 1                1                  7            0                  CC
# 2                1                  3          3.4                  CC
# 3                1                  7            0                  CC
# 4                1                  3            3                  CC
# ..             ...                ...          ...                 ...
# 77               1                  0           **                  CC
# 78               1                  3          3.4                  CC
# 79               1                  0           **                  CC
# 80               1                  0           **                  CC
# 81               1                  7            0                  CC
#
#     Identificación Primer Nombre Segundo Nombre Primer Apellido  \
# ...

# %%
# df_csv
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 60 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Tipo Cotizante                 82 non-null     int64
#  1   Subtipo Cotizante              82 non-null     int64
#  2   Subtipo UGPP                   82 non-null     object
#  3   Tipo Identificacion            82 non-null     object
#  4   Identificación                 82 non-null     int64
#  5   Primer Nombre                  82 non-null     object
#  6   Segundo Nombre                 51 non-null     object
#  7   Primer Apellido                82 non-null     object
#  8   Segundo Apellido               81 non-null     object
#  9   Tipo Sexo                      82 non-null     object
#  10  Salario o IBC                  82 non-null     int64
#  11  Cotizante Extranjero           82 non-null     object
# ...

# %%
df_csv.dtypes
# Out:
# Tipo Cotizante                     int64
# Subtipo Cotizante                  int64
# Subtipo UGPP                      object
# Tipo Identificacion               object
# Identificación                     int64
# Primer Nombre                     object
# Segundo Nombre                    object
# Primer Apellido                   object
# Segundo Apellido                  object
# Tipo Sexo                         object
# Salario o IBC                      int64
# Cotizante Extranjero              object
# Fecha Nacimiento                  object
# Edad                               int64
# Fecha Expedición                  object
# Numero Telefono                   object
# Numero Celular                    object
# Dirección                         object
# Ciudad - Departamento             object
# Email                             object
# Vlr Administracion                 int64
# Vlr UPC                            int64
# Identificacion Cotizante UPC       int64
# ...

# %%
# Assuming df is your DataFrame
import re

# Assuming df_csv is your DataFrame
columns_list = df_csv.columns

# Use a list comprehension to replace spaces and hyphens with underscores in each column name
#The extra regex is just for the previous Ciudad_-_Departamento  correction
# Use a list comprehension with a single regular expression for all substitutions
columns_with_underscores = [re.sub(r'\s+|-|Vlr -', lambda x: '_' if x.group() == ' ' else 'Valor_', column) for column in columns_list]

# Assign the new column names to the DataFrame
df_csv.columns = columns_with_underscores

# Display the DataFrame with updated column names
df_csv
# Out:
#     Tipo_Cotizante  Subtipo_Cotizante Subtipo_UGPP Tipo_Identificacion  \
# 0                1                  7            0                  CC
# 1                1                  7            0                  CC
# 2                1                  3          3.4                  CC
# 3                1                  7            0                  CC
# 4                1                  3            3                  CC
# 5                1                  7            0                  CC
# 6                1                  3            3                  CC
# 7                1                  7            0                  CC
# 8                1                  3            3                  CC
# 9                1                  0           **                  CC
# 10               1                  3          3.4                  CC
# 11               1                  7            0                  CC
# ...

# %%
df_csv.describe()
# Out:
#        Tipo_Cotizante  Subtipo_Cotizante  Identificación  Salario_o_IBC  \
# count            82.0          82.000000    8.200000e+01           82.0
# mean              1.0           4.158537    3.670714e+08      1160000.0
# std               0.0           2.852201    4.948123e+08            0.0
# min               1.0           0.000000    4.919812e+06      1160000.0
# 25%               1.0           3.000000    3.129542e+07      1160000.0
# 50%               1.0           3.000000    5.810930e+07      1160000.0
# 75%               1.0           7.000000    1.073505e+09      1160000.0
# max               1.0           7.000000    1.151939e+09      1160000.0
#
#             Edad  Vlr_Administracion  Vlr_UPC  Identificacion_Cotizante_UPC  \
# count  82.000000           82.000000     82.0                          82.0
# mean   47.280488        45232.926829      0.0                           0.0
# std    16.031046         6210.585445      0.0                           0.0
# ...

# %%
import seaborn as sns
sns.pairplot(df_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_matrix = df_csv.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
df_csv.hist()
plt.show()

# %%
print(df_csv.columns)
print(len(df_csv.columns))
# Out:
# Index(['Tipo_Cotizante', 'Subtipo_Cotizante', 'Subtipo_UGPP',
#        'Tipo_Identificacion', 'Identificación', 'Primer_Nombre',
#        'Segundo_Nombre', 'Primer_Apellido', 'Segundo_Apellido', 'Tipo_Sexo',
#        'Salario_o_IBC', 'Cotizante_Extranjero', 'Fecha_Nacimiento', 'Edad',
#        'Fecha_Expedición', 'Numero_Telefono', 'Numero_Celular', 'Dirección',
#        'Ciudad_Valor__Departamento', 'Email', 'Vlr_Administracion', 'Vlr_UPC',
#        'Identificacion_Cotizante_UPC', 'Excento_de_1607', 'Centro_Trabajo',
#        'Numero_Folio', 'Mensajeria', 'Vlr_Mensajeria', 'Estado',
#        'Identificacion_Asesor', 'Nombre_Asesor', 'Valor_Comision',
#        'Nit_Empresa_Servicio', 'Razon_Social_Empresa_Servicio',
#        'Fecha_Afiliación', 'AFP', 'AFPTarifa', 'EPS', 'EPSTarifa', 'ARL',
#        'ARLTarifa', 'ARL_Nivel', 'CodCIIU', 'Planilla_N', 'CCF',
#        'CiudadValor_CCF', 'CCFTarifa', 'SENA', 'SENATarifa', 'ICBF',
# ...

# %%
df_csv.isna().sum()
# Out:
# Tipo_Cotizante                    0
# Subtipo_Cotizante                 0
# Subtipo_UGPP                      0
# Tipo_Identificacion               0
# Identificación                    0
# Primer_Nombre                     0
# Segundo_Nombre                   31
# Primer_Apellido                   0
# Segundo_Apellido                  1
# Tipo_Sexo                         0
# Salario_o_IBC                     0
# Cotizante_Extranjero              0
# Fecha_Nacimiento                  0
# Edad                              0
# Fecha_Expedición                  0
# Numero_Telefono                   0
# Numero_Celular                    1
# Dirección                         0
# Ciudad_Valor__Departamento        0
# Email                             9
# Vlr_Administracion                0
# Vlr_UPC                           0
# Identificacion_Cotizante_UPC      0
# Excento_de_1607                   0
# Centro_Trabajo                   80
# Numero_Folio                     82
# ...

# %%
df_csv.loc[df_csv.duplicated()]

# %%
df_csv.loc[df_csv.duplicated(subset=['Subtipo_Cotizante'])].head(5)

# %%
df_csv.query('Subtipo_Cotizante == 7')
# df_csv.loc[df_csv.duplicated(subset=['Subtipo_Cotizante'])]

# %% [markdown]
# # Step 2: Univariate numerical analysis

# %%
df_csv["Fecha_Afiliación"]=pd.to_datetime(df_csv["Fecha_Afiliación"])
df_csv["Fecha_Nacimiento"]=pd.to_datetime(df_csv["Fecha_Nacimiento"])
df_csv["Fecha_Expedición"]=pd.to_datetime(df_csv["Fecha_Expedición"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11560/2132764021.py in <module>
# ----> 1 df_csv["Fecha_Afiliación"]=pd.to_datetime(df_csv["Fecha_Afiliación"])
#       2 df_csv["Fecha_Nacimiento"]=pd.to_datetime(df_csv["Fecha_Nacimiento"])
#       3 df_csv["Fecha_Expedición"]=pd.to_datetime(df_csv["Fecha_Expedición"])
#
# NameError: name 'df_csv' is not defined

# %%
df_csv.head(8)
# Out:
#    Tipo_Cotizante  Subtipo_Cotizante Subtipo_UGPP Tipo_Identificacion  \
# 0               1                  7            0                  CC
# 1               1                  7            0                  CC
# 2               1                  3          3.4                  CC
# 3               1                  7            0                  CC
# 4               1                  3            3                  CC
# 5               1                  7            0                  CC
# 6               1                  3            3                  CC
# 7               1                  7            0                  CC
#
#    Identificación Primer_Nombre Segundo_Nombre Primer_Apellido  \
# 0        38596006         MARIA      TERSELINA         AGUILAR
# 1        94537793         JONNY      ALEXANDER         ALARCON
# 2        31952188     ROSALBINA            NaN        ALMENDRA
# 3      1130637513      HERMINIA         ANDREA        ALVARADO
# ...

# %%
df[["Subtipo_Cotizante", "Identificación", "Subtipo_UGPP",	"Tipo_Identificacion"	Identificación	Primer_Nombre	Segundo_Nombre	Primer_Apellido	Segundo_Apellido	Tipo_Sexo	Salario_o_IBC	"Salario_o_IBC",	"Edad",	"Vlr_Administracion", ]]

# %%
df_csv_clean= df_csv[[#'Tipo_Cotizante',
    'Subtipo_Cotizante', 'Subtipo_UGPP',
       'Tipo_Identificacion', 'Identificación', 'Primer_Nombre',
       'Segundo_Nombre', 'Primer_Apellido', 'Segundo_Apellido', 'Tipo_Sexo',
       'Salario_o_IBC', 
#     'Cotizante_Extranjero',
    'Fecha_Nacimiento', 'Edad',
       'Fecha_Expedición', 'Numero_Telefono', 'Numero_Celular', 'Dirección',
       'Ciudad_Valor__Departamento', 'Email', 'Vlr_Administracion', 
#     'Vlr_UPC',       'Identificacion_Cotizante_UPC', 
    'Excento_de_1607', 
#     'Centro_Trabajo',
#        'Numero_Folio','Mensajeria', 'Vlr_Mensajeria', 
    'Estado',
#    'Identificacion_Asesor', 'Nombre_Asesor', 'Valor_Comision',
#        'Nit_Empresa_Servicio', 'Razon_Social_Empresa_Servicio',
       'Fecha_Afiliación', 'AFP', 'AFPTarifa', 'EPS', 'EPSTarifa', 'ARL',
       'ARLTarifa', 'ARL_Nivel', 'CodCIIU', 
#     'Planilla_N', 'CCF',
       'CiudadValor_CCF', 'CCFTarifa', 
    'SENA', 'SENATarifa', 'ICBF',       'ICBTarifa', 'Valor_PILA', 
#     'Valor_Otros', 
    'Valor_Total',
       'Incapacidades', 'Tipo_Periodo', 'Modo_Recaudo', 'Numero_Nit',
       'Razon_Social', 'Observaciones']].copy()

# %%
df_csv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Subtipo_Cotizante           82 non-null     int64
#  1   Subtipo_UGPP                82 non-null     object
#  2   Tipo_Identificacion         82 non-null     object
#  3   Identificación              82 non-null     int64
#  4   Primer_Nombre               82 non-null     object
#  5   Segundo_Nombre              51 non-null     object
#  6   Primer_Apellido             82 non-null     object
#  7   Segundo_Apellido            81 non-null     object
#  8   Tipo_Sexo                   82 non-null     object
#  9   Salario_o_IBC               82 non-null     int64
#  10  Fecha_Nacimiento            82 non-null     datetime64[ns]
#  11  Edad                        82 non-null     int64
#  12  Fecha_Expedición            82 non-null     datetime64[ns]
# ...

# %%
affiliation_Year= [df_csv["Fecha_Afiliación"][i].year for i, _ in enumerate(df_csv["Fecha_Afiliación"])]
birth_year=[df_csv["Fecha_Nacimiento"][i].year for i, _ in enumerate(df_csv["Fecha_Nacimiento"])]
exp_year= [df_csv["Fecha_Expedición"][i].year for i, _ in enumerate(df_csv["Fecha_Expedición"])]

# %%
print(len(affiliation_Year))
# Out:
# 82

# %%
df_csv_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Subtipo_Cotizante           82 non-null     int64
#  1   Subtipo_UGPP                82 non-null     object
#  2   Tipo_Identificacion         82 non-null     object
#  3   Identificación              82 non-null     int64
#  4   Primer_Nombre               82 non-null     object
#  5   Segundo_Nombre              51 non-null     object
#  6   Primer_Apellido             82 non-null     object
#  7   Segundo_Apellido            81 non-null     object
#  8   Tipo_Sexo                   82 non-null     object
#  9   Salario_o_IBC               82 non-null     int64
#  10  Fecha_Nacimiento            82 non-null     object
#  11  Edad                        82 non-null     int64
#  12  Fecha_Expedición            82 non-null     object
# ...

# %%
df_csv_clean=df_csv_clean.rename(columns={ "Ciudad_Valor__Departamento": "Ciudad_o_Valor", 
                   "Vlr_Administracion": "Valor_Administracion ",
                   "CodCIIU": "Cod_CIIU",
                   "CiudadValor_CCF": "Ciudad_Valor_CCF",
                   "CCFTarifa": "CCF_Tarifa",
                   "ICBTarifa": "ICBF_Tarifa",
                    "AFPTarifa" : " AFP_Tarifa",
                   "ARLTarifa": "ARL_Tarifa",
                   "EPSTarifa": "EPS_Tarifa"
                  })

# %%
# Extract the year from each date
df_csv_clean['Year_of_Birth'] = df_csv_clean['Fecha_Nacimiento'].dt.year

# %%
ax= df_csv_clean['Year_of_Birth'].value_counts()\
                             .head(10)\
                             .plot(kind='bar', title='Edades de interes para captar afiliados')
ax.set_xlabel('Año de nacimiento')
ax.set_ylabel('Cantidad de Afiliados')
# Out:
# Text(0, 0.5, 'Cantidad de Afiliados')

# %%
ax= df_csv_clean['Year_of_Birth'].plot(kind='hist', bins=20, title='Afiliados por año de nacimiento')
ax.set_xlabel('Año de nacimiento')
ax.set_ylabel('Cantidad')
ax.set_xlim([1940, 2022])
# Out:
# (1940.0, 2022.0)

# %%
ax= df_csv_clean['Year_of_Birth'].plot(kind='kde', title='Afiliados por año de nacimiento')
ax.set_xlabel('Año de nacimiento')
ax.set_ylabel('Densidad')
ax.set_xlim([1930, 2022])
# Out:
# (1930.0, 2022.0)

# %%
df_csv_clean.head()
# Out:
#    Subtipo_Cotizante Subtipo_UGPP Tipo_Identificacion  Identificación  \
# 0                  7            0                  CC        38596006
# 1                  7            0                  CC        94537793
# 2                  3          3.4                  CC        31952188
# 3                  7            0                  CC      1130637513
# 4                  3            3                  CC        12127358
#
#   Primer_Nombre Segundo_Nombre Primer_Apellido Segundo_Apellido Tipo_Sexo  \
# 0         MARIA      TERSELINA         AGUILAR          ZUÃ‘IGA         F
# 1         JONNY      ALEXANDER         ALARCON           GARCIA         M
# 2     ROSALBINA            NaN        ALMENDRA          SANCHEZ         F
# 3      HERMINIA         ANDREA        ALVARADO         LONDOÃ‘O         F
# 4        HECTOR       FERNANDO         ALVAREZ           CASTRO         M
#
#    Salario_o_IBC Fecha_Nacimiento  Edad Fecha_Expedición Numero_Telefono  \
# ...

# %%
df_csv_clean.plot(kind='scatter', x="Year_of_Birth", y="Valor_Total", title="Valor cotizado vs edad cotizante")
# Out:
# <AxesSubplot:title={'center':'Valor cotizado vs edad cotizante'}, xlabel='Year_of_Birth', ylabel='Valor_Total'>

# %%
sns.scatterplot(x="Year_of_Birth", y="Valor_Total", hue='ARL_Nivel', data= df_csv_clean)
# Out:
# <AxesSubplot:xlabel='Year_of_Birth', ylabel='Valor_Total'>

# %%
sns.pairplot(df_csv_clean, vars=['Year_of_Birth', 'Valor_Total', 'ARL_Nivel'], hue='EPS')
plt.show()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(df_csv_clean, vars=['Year_of_Birth', "Valor_Total", 'ARL_Nivel', 'Tipo_Sexo_Cat'], hue="EPS")
plt.show()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\camil\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df_corr= df_csv_clean[['Year_of_Birth', 'Valor_Total', 'ARL_Nivel', 'EPS_Cat', 'Tipo_Sexo_Cat']].dropna().corr()

# %%
df_csv_clean['Tipo_Sexo_Cat'] = [ 0 if df_csv_clean['Tipo_Sexo'][i] =='F' else 1 for i, sex in enumerate(df_csv_clean['Tipo_Sexo'])]

# %%
unique_values = df_csv_clean['EPS'].unique()
df_csv_clean['EPS_Cat'] = df_csv_clean['EPS'].replace({
    'EPS SANITAS': 1,
    'EPS SURA': 2,
    'NUEVA EPS': 3,
    'COMPENSAR EPS': 4,
    'S.O.S EPS': 5,
    'SALUD TOTAL EPS': 6,
    'EMSSANAR EPS': 7,
    'COMFENALCO VALLE EPS': 8,
    'EPS-S COOSALUD': 9,
    'RECAUDO SGP CAPITAL SALUD': 10,
    'ALIANSALUD E.P.S.': 11
})

# %%
print(len(unique_values))
# Out:
# 11

# %%
sns.heatmap(df_corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
df_csv_clean['EPS'].value_counts()
# Out:
# EPS SURA                     21
# EPS SANITAS                  18
# NUEVA EPS                    14
# S.O.S EPS                    11
# SALUD TOTAL EPS               8
# COMFENALCO VALLE EPS          5
# EPS-S COOSALUD                1
# COMPENSAR EPS                 1
# ALIANSALUD E.P.S.             1
# EMSSANAR EPS                  1
# RECAUDO SGP CAPITAL SALUD     1
# Name: EPS, dtype: int64

# %%
df_csv_clean['ARL_Nivel'].value_counts()
# Out:
# 1    69
# 0     5
# 4     5
# 3     2
# 2     1
# Name: ARL_Nivel, dtype: int64

# %%
df_csv_clean["AFP"].value_counts()
# Out:
# PORVENIR        24
# COLPENSIONES    19
# PROTECCION       8
# COLFONDOS        5
# Name: AFP, dtype: int64

# %%
not_null_rows = df_csv_clean[~df_csv_clean["AFP"].isna()]
print(len(not_null_rows))
# Out:
# 56
